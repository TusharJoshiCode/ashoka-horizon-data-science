# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/home/tushar/horizon25/ashoka-horizon-data-science/week-3/data/pima/diabetes.csv")
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Matplotlib
fig_mpl_hits, ax_mlp_hits = plt.subplots

# %%
# Seaborn

# %%
cancer_data =  pd.read_csv("/home/tushar/horizon25/ashoka-horizon-data-science/week-3/data/breast-cancer/data.csv")
cancer_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Matplotlin
# permeter_mean_data
fig_mpl_hits, ax_mlp_hits = plt.subplots(figsize=(5,3))
ax_

# %%
cancer_data["diagnosis"].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
fig, ax = plt.subplot(figsize=(5,4))
sns.countplot(
    data = cancer_data
    y="diagnosis"
    
)
# Out:
#   Cell In[10], line 3
#     data=cancer_data
#          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

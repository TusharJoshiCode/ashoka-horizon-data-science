# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/home/tushar/horizon25/ashoka-horizon-data-science/week-3/data/pima/diabetes.csv")
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
fig, ax = plt.subplots(figsize=(5,3))
sns.scatterplot(

    data=data,
    x="Glucose",
    y="BMI",
    ax=ax,
    color='red'
)
ax.set_title("Scatter PLot Between Glucose ANd BMI")
x.set_xlabel("Glucose")
x.set_ylabel("BMI")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 11
#       2 sns.scatterplot(
#       3
#       4     data=data,
#    (...)      8     color='red'
#       9 )
#      10 ax.set_title("Scatter PLot Between Glucose ANd BMI")
# ---> 11 x.set_xlabel("Glucose")
#      12 x.set_ylabel("BMI")
#      13 plt.show()
#
# NameError: name 'x' is not defined

# %%
fig, ax = plt.subplots(figsize=(5, 3))
sns.jointplot(
    data=data_,
    x="Glucose",
    y="Insulin",
    ax=ax,
    color='#06202B'
)
ax.set_title("Joint Plot between Glucose and Insulin")
ax.set_xlabel("Glucose")
ax.set_ylabel("Insulin")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 fig, ax = plt.subplots(figsize=(5, 3))
#       2 sns.jointplot(
# ----> 3     data=data_,
#       4     x="Glucose",
#       5     y="Insulin",
#       6     ax=ax,
#       7     color='#06202B'
#       8 )
#       9 ax.set_title("Joint Plot between Glucose and Insulin")
#      10 ax.set_xlabel("Glucose")
#
# NameError: name 'data_' is not defined

# %%
data_corr = dta_.cor()
data_corr_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data_corr = dta_.cor()
#       2 data_corr_
#
# NameError: name 'dta_' is not defined

# %%
sns.heatmap(data_corr_)
